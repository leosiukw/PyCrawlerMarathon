# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
# ANS: 「File I/O」讀出來的內容比較亂，而且不能輕易閱讀，相反「xmltodict」讀出來的內容比較有組織，較容易抽取想要的資料

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？

# 讀檔案
encoding ='utf-8'
fh = open("./data/64_72hr_CH.xml", "r", encoding=encoding)
xml = fh.read()
fh.close()

# 解析檔案內容
import xmltodict
d = dict(xmltodict.parse(xml))

locations = d['cwbopendata']['dataset']['locations']['location']
for location in locations:
    print(location['locationName'])
# Out:
# 鹽埕區
# 鼓山區
# 左營區
# 楠梓區
# 三民區
# 新興區
# 前金區
# 苓雅區
# 前鎮區
# 旗津區
# 小港區
# 鳳山區
# 林園區
# 大寮區
# 大樹區
# 大社區
# 仁武區
# 鳥松區
# 岡山區
# 橋頭區
# 燕巢區
# 田寮區
# 阿蓮區
# 路竹區
# 湖內區
# 茄萣區
# 永安區
# 彌陀區
# 梓官區
# 旗山區
# 美濃區
# 六龜區
# 甲仙區
# 杉林區
# 內門區
# 茂林區
# 桃源區
# 那瑪夏區

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

for location in locations:
    for weatherElement in location['weatherElement']:
        if weatherElement['description'] == '溫度': 
            print(location['locationName'], weatherElement['time'][0]['dataTime'], weatherElement['time'][0]['elementValue']['value'])
# Out:
# 鹽埕區 2020-06-19T06:00:00+08:00 28
# 鼓山區 2020-06-19T06:00:00+08:00 28
# 左營區 2020-06-19T06:00:00+08:00 28
# 楠梓區 2020-06-19T06:00:00+08:00 27
# 三民區 2020-06-19T06:00:00+08:00 28
# 新興區 2020-06-19T06:00:00+08:00 28
# 前金區 2020-06-19T06:00:00+08:00 28
# 苓雅區 2020-06-19T06:00:00+08:00 28
# 前鎮區 2020-06-19T06:00:00+08:00 28
# 旗津區 2020-06-19T06:00:00+08:00 28
# 小港區 2020-06-19T06:00:00+08:00 27
# 鳳山區 2020-06-19T06:00:00+08:00 27
# 林園區 2020-06-19T06:00:00+08:00 27
# 大寮區 2020-06-19T06:00:00+08:00 27
# 大樹區 2020-06-19T06:00:00+08:00 25
# 大社區 2020-06-19T06:00:00+08:00 27
# 仁武區 2020-06-19T06:00:00+08:00 27
# 鳥松區 2020-06-19T06:00:00+08:00 27
# 岡山區 2020-06-19T06:00:00+08:00 27
# 橋頭區 2020-06-19T06:00:00+08:00 27
# 燕巢區 2020-06-19T06:00:00+08:00 26
# 田寮區 2020-06-19T06:00:00+08:00 26
# 阿蓮區 2020-06-19T06:00:00+08:00 26
# 路竹區 2020-06-19T06:00:00+08:00 27
# 湖內區 2020-06-19T06:00:00+08:00 27
# 茄萣區 2020-06-19T06:00:00+08:00 27
# 永安區 2020-06-19T06:00:00+08:00 27
# 彌陀區 2020-06-19T06:00:00+08:00 26
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

for weatherElement in locations[0]['weatherElement']:
    if weatherElement['description'] == '溫度': 
        for time in weatherElement['time']:
            print(locations[0]['locationName'],time['dataTime'], time['elementValue']['value'])
# Out:
# 鹽埕區 2020-06-19T06:00:00+08:00 28
# 鹽埕區 2020-06-19T09:00:00+08:00 31
# 鹽埕區 2020-06-19T12:00:00+08:00 32
# 鹽埕區 2020-06-19T15:00:00+08:00 32
# 鹽埕區 2020-06-19T18:00:00+08:00 31
# 鹽埕區 2020-06-19T21:00:00+08:00 30
# 鹽埕區 2020-06-20T00:00:00+08:00 29
# 鹽埕區 2020-06-20T03:00:00+08:00 29
# 鹽埕區 2020-06-20T06:00:00+08:00 28
# 鹽埕區 2020-06-20T09:00:00+08:00 31
# 鹽埕區 2020-06-20T12:00:00+08:00 32
# 鹽埕區 2020-06-20T15:00:00+08:00 32
# 鹽埕區 2020-06-20T18:00:00+08:00 31
# 鹽埕區 2020-06-20T21:00:00+08:00 30
# 鹽埕區 2020-06-21T00:00:00+08:00 29
# 鹽埕區 2020-06-21T03:00:00+08:00 28
# 鹽埕區 2020-06-21T06:00:00+08:00 28
# 鹽埕區 2020-06-21T09:00:00+08:00 31
# 鹽埕區 2020-06-21T12:00:00+08:00 32
# 鹽埕區 2020-06-21T15:00:00+08:00 32
# 鹽埕區 2020-06-21T18:00:00+08:00 31
# 鹽埕區 2020-06-21T21:00:00+08:00 30
# 鹽埕區 2020-06-22T00:00:00+08:00 29
# 鹽埕區 2020-06-22T03:00:00+08:00 28
